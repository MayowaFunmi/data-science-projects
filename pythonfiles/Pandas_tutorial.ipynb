# %%
import pandas as pd
import numpy as np

# %%
# Example of Series
data = np.array(['a', 'b', 'c', 'd'])
s = pd.Series(data, index=[1, 2, 3, 4])
s
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
# Example of DataFrame
data = [1, 2, 3, 4, 5]
df = pd.DataFrame(data)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data2 = [['Alex', 10], ['Bob', 12], ['Clarke', 33]]
df1 = pd.DataFrame(data2, columns=['Name', 'Age'], index=[1, 2, 3])
df1
# Out:
#      Name  Age
# 1    Alex   10
# 2     Bob   12
# 3  Clarke   33

# %%
data3 = {'Name': ['Tom', 'Jack', 'Steve', 'Ricky'], 'Age': [28, 54, 87, 12], 'Occupation':['Teacher', 'Accountant', 'Engineer', 'Doctor']}
df2 = pd.DataFrame(data3, index=[1, 2, 3, 4])
df2
# Out:
#     Name  Age  Occupation
# 1    Tom   28     Teacher
# 2   Jack   54  Accountant
# 3  Steve   87    Engineer
# 4  Ricky   12      Doctor

# %%
data4 = [{'a': 1, 'b': 2, 'd': 4}, {'a': 5, 'b': 10, 'c': 20, 'd': 55}]
df3 = pd.DataFrame(data4, index=[1, 2])
df3
# Out:
#    a   b   d     c
# 1  1   2   4   NaN
# 2  5  10  55  20.0

# %%
# examples of panel
data5 = [10, 20, 30]
data5
# Out:
# [10, 20, 30]

# %%
# panel class has been removed

# %%
# reading data from csv file
df5 = pd.read_csv('/home/mayowafunmi/Documents/udemy-data-science/Section 1/hrdata.csv')
df5
# Out:
#              Name   Hire Date  Salary  Sick Days remaining
# 0  Graham Chapman    03/15/14   50000                   10
# 1     John Cleese  06-01-2015   65000                    8
# 2       Eric Idle  05-12-2014   45000                   10
# 3     Terry Jones  11-01-2013   70000                    3
# 4   Terry Gilliam  08-12-2014   48000                    7
# 5   Michael Palin    05/23/13   66000                    8

# %%
df5['Name']
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2         Eric Idle
# 3       Terry Jones
# 4     Terry Gilliam
# 5     Michael Palin
# Name: Name, dtype: object

# %%
df5['Salary'] # double brackets shows heading/name of colum
# Out:
# 0    50000
# 1    65000
# 2    45000
# 3    70000
# 4    48000
# 5    66000
# Name: Salary, dtype: int64

# %%
salary = df5['Salary']
sum(salary)
# Out:
# 344000

# %%
df5[['Salary', 'Name']]
# Out:
#    Salary            Name
# 0   50000  Graham Chapman
# 1   65000     John Cleese
# 2   45000       Eric Idle
# 3   70000     Terry Jones
# 4   48000   Terry Gilliam
# 5   66000   Michael Palin

# %%
# generate one random row
df5.sample(n=1)
# Out:
#         Name   Hire Date  Salary  Sick Days remaining
# 2  Eric Idle  05-12-2014   45000                   10

# %%
df5.shape
# Out:
# (6, 4)

# %% [markdown]
# # Adding new column in dataframe

# %%
number_of_leaves = [0, 2, 0, 7, 3, 2]
df5['Leaves Taken'] = number_of_leaves
df5
# Out:
#              Name   Hire Date  Salary  Sick Days remaining  Leaves Taken
# 0  Graham Chapman    03/15/14   50000                   10             0
# 1     John Cleese  06-01-2015   65000                    8             2
# 2       Eric Idle  05-12-2014   45000                   10             0
# 3     Terry Jones  11-01-2013   70000                    3             7
# 4   Terry Gilliam  08-12-2014   48000                    7             3
# 5   Michael Palin    05/23/13   66000                    8             2

# %%
df5.shape
# Out:
# (6, 5)

# %%
gender = ['M', 'F', 'M', 'M', 'F', 'M']
df5['Gender'] = gender
df5
# Out:
#              Name   Hire Date  Salary  Sick Days remaining  Leaves Taken  \
# 0  Graham Chapman    03/15/14   50000                   10             0
# 1     John Cleese  06-01-2015   65000                    8             2
# 2       Eric Idle  05-12-2014   45000                   10             0
# 3     Terry Jones  11-01-2013   70000                    3             7
# 4   Terry Gilliam  08-12-2014   48000                    7             3
# 5   Michael Palin    05/23/13   66000                    8             2
#
#   Gender
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
# 5      M

# %%
del df5['Gender']
df5
# Out:
#              Name   Hire Date  Salary  Sick Days remaining  Leaves Taken
# 0  Graham Chapman    03/15/14   50000                   10             0
# 1     John Cleese  06-01-2015   65000                    8             2
# 2       Eric Idle  05-12-2014   45000                   10             0
# 3     Terry Jones  11-01-2013   70000                    3             7
# 4   Terry Gilliam  08-12-2014   48000                    7             3
# 5   Michael Palin    05/23/13   66000                    8             2

# %%
import pandas as pd
file = pd.read_csv('/home/mayowafunmi/Documents/udemy-data-science/Section 1/Cricket.csv')
file
# Out:
#     Delivery  score_india  score_pk
# 0        0.1            0         0
# 1        0.2            1         0
# 2        0.3            1         0
# 3        0.4            4         4
# 4        0.5            0         2
# 5        0.6            2         4
# 6        1.1            0         0
# 7        1.2            0         0
# 8        1.3            0         2
# 9        1.4            1         1
# 10       1.5            4         3
# 11       1.6            1         2
# 12       2.1            2         1
# 13       2.2            0         1
# 14       2.3            3         2
# 15       2.4            0         1
# 16       2.5            1         0
# 17       2.6            0         2
# 18       3.1            4         2
# 19       3.2            0         4
# 20       3.3            4         1
# 21       3.4            3         4
# 22       3.5            1         0
# 23       3.6            2         1

# %%
# display only first five elements of the data
file.head()
# Out:
#    Delivery  score_india  score_pk
# 0       0.1            0         0
# 1       0.2            1         0
# 2       0.3            1         0
# 3       0.4            4         4
# 4       0.5            0         2

# %%
# display only last five elements
file.tail()
# Out:
#     Delivery  score_india  score_pk
# 19       3.2            0         4
# 20       3.3            4         1
# 21       3.4            3         4
# 22       3.5            1         0
# 23       3.6            2         1

# %%
file['Delivery'].head()
# Out:
# 0    0.1
# 1    0.2
# 2    0.3
# 3    0.4
# 4    0.5
# Name: Delivery, dtype: float64

# %%
# display first 10 elements
file.head(10)
# Out:
#    Delivery  score_india  score_pk
# 0       0.1            0         0
# 1       0.2            1         0
# 2       0.3            1         0
# 3       0.4            4         4
# 4       0.5            0         2
# 5       0.6            2         4
# 6       1.1            0         0
# 7       1.2            0         0
# 8       1.3            0         2
# 9       1.4            1         1

# %%
# get specific element in the table
file['score_india'][5]
# Out:
# 2

# %% [markdown]
# # Sorting the DataFrame based on a column

# %%
# rearrange values given the parameters for rearrangement
file.sort_values('score_india')
# Out:
#     Delivery  score_india  score_pk
# 0        0.1            0         0
# 19       3.2            0         4
# 17       2.6            0         2
# 4        0.5            0         2
# 15       2.4            0         1
# 6        1.1            0         0
# 7        1.2            0         0
# 8        1.3            0         2
# 13       2.2            0         1
# 16       2.5            1         0
# 22       3.5            1         0
# 11       1.6            1         2
# 9        1.4            1         1
# 2        0.3            1         0
# 1        0.2            1         0
# 12       2.1            2         1
# 5        0.6            2         4
# 23       3.6            2         1
# 14       2.3            3         2
# 21       3.4            3         4
# 3        0.4            4         4
# 18       3.1            4         2
# 20       3.3            4         1
# 10       1.5            4         3

# %%
file.sort_values('score_pk')
# Out:
#     Delivery  score_india  score_pk
# 0        0.1            0         0
# 1        0.2            1         0
# 2        0.3            1         0
# 16       2.5            1         0
# 6        1.1            0         0
# 7        1.2            0         0
# 22       3.5            1         0
# 20       3.3            4         1
# 15       2.4            0         1
# 13       2.2            0         1
# 12       2.1            2         1
# 23       3.6            2         1
# 9        1.4            1         1
# 8        1.3            0         2
# 14       2.3            3         2
# 4        0.5            0         2
# 17       2.6            0         2
# 18       3.1            4         2
# 11       1.6            1         2
# 10       1.5            4         3
# 5        0.6            2         4
# 19       3.2            0         4
# 3        0.4            4         4
# 21       3.4            3         4

# %%
# sort in descending order, ascending order is default
file.sort_values('score_pk', ascending=False)
# Out:
#     Delivery  score_india  score_pk
# 21       3.4            3         4
# 3        0.4            4         4
# 5        0.6            2         4
# 19       3.2            0         4
# 10       1.5            4         3
# 14       2.3            3         2
# 4        0.5            0         2
# 8        1.3            0         2
# 18       3.1            4         2
# 11       1.6            1         2
# 17       2.6            0         2
# 12       2.1            2         1
# 20       3.3            4         1
# 15       2.4            0         1
# 23       3.6            2         1
# 13       2.2            0         1
# 9        1.4            1         1
# 16       2.5            1         0
# 1        0.2            1         0
# 7        1.2            0         0
# 6        1.1            0         0
# 2        0.3            1         0
# 22       3.5            1         0
# 0        0.1            0         0

# %%
# count number of unique values that occur in dataset or in a column
file.nunique()
# Out:
# Delivery       24
# score_india     5
# score_pk        5
# dtype: int64

# %%
sum(file['score_india'])
# Out:
# 34

# %% [markdown]
# # Indexing Using Labels in pandas

# %%
# using loc()
file
# Out:
#     Delivery  score_india  score_pk
# 0        0.1            0         0
# 1        0.2            1         0
# 2        0.3            1         0
# 3        0.4            4         4
# 4        0.5            0         2
# 5        0.6            2         4
# 6        1.1            0         0
# 7        1.2            0         0
# 8        1.3            0         2
# 9        1.4            1         1
# 10       1.5            4         3
# 11       1.6            1         2
# 12       2.1            2         1
# 13       2.2            0         1
# 14       2.3            3         2
# 15       2.4            0         1
# 16       2.5            1         0
# 17       2.6            0         2
# 18       3.1            4         2
# 19       3.2            0         4
# 20       3.3            4         1
# 21       3.4            3         4
# 22       3.5            1         0
# 23       3.6            2         1

# %%
# select row number 4 data
file.loc[4]
# Out:
# Delivery       0.5
# score_india    0.0
# score_pk       2.0
# Name: 4, dtype: float64

# %%
# select from row 1 to 4
file.loc[1:4]
# Out:
#    Delivery  score_india  score_pk
# 1       0.2            1         0
# 2       0.3            1         0
# 3       0.4            4         4
# 4       0.5            0         2

# %%
# select first five rows including 5th index and every columns of the file
file.loc[0:5, :]
# Out:
#    Delivery  score_india  score_pk
# 0       0.1            0         0
# 1       0.2            1         0
# 2       0.3            1         0
# 3       0.4            4         4
# 4       0.5            0         2
# 5       0.6            2         4

# %%
# select from 5th row onwards
file.loc[5:, :]
# Out:
#     Delivery  score_india  score_pk
# 5        0.6            2         4
# 6        1.1            0         0
# 7        1.2            0         0
# 8        1.3            0         2
# 9        1.4            1         1
# 10       1.5            4         3
# 11       1.6            1         2
# 12       2.1            2         1
# 13       2.2            0         1
# 14       2.3            3         2
# 15       2.4            0         1
# 16       2.5            1         0
# 17       2.6            0         2
# 18       3.1            4         2
# 19       3.2            0         4
# 20       3.3            4         1
# 21       3.4            3         4
# 22       3.5            1         0
# 23       3.6            2         1

# %%
# computes various summary statistics
file.describe()
# Out:
#         Delivery  score_india   score_pk
# count  24.000000    24.000000  24.000000
# mean    1.850000     1.416667   1.541667
# std     1.155328     1.501207   1.413573
# min     0.100000     0.000000   0.000000
# 25%     0.975000     0.000000   0.000000
# 50%     1.850000     1.000000   1.000000
# 75%     2.725000     2.250000   2.000000
# max     3.600000     4.000000   4.000000

# %% [markdown]
# # Filtering under one condition

# %%
# select all rows with a condition
# show boolean values of >= 2 condition 
filter1 = file['score_india'] >= 2

# %%
filter1
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20     True
# 21     True
# 22    False
# 23     True
# Name: score_india, dtype: bool

# %%
# show the table with elements >= 2
file[filter1]
# Out:
#     Delivery  score_india  score_pk
# 3        0.4            4         4
# 5        0.6            2         4
# 10       1.5            4         3
# 12       2.1            2         1
# 14       2.3            3         2
# 18       3.1            4         2
# 20       3.3            4         1
# 21       3.4            3         4
# 23       3.6            2         1

# %% [markdown]
# # Selecting rows with indices using "iloc"

# %%
# select rows with indices 0 and 5 only
file.iloc[[2, 5]] # same as using loc[[2, 5]]
# Out:
#    Delivery  score_india  score_pk
# 2       0.3            1         0
# 5       0.6            2         4

# %%
# select rows with particular indices and particular colums
# ist array select rows, second array select colums
file.iloc[[0, 2, 4, 6, 8, 10], [1, 2]]
# Out:
#     score_india  score_pk
# 0             0         0
# 2             1         0
# 4             0         2
# 6             0         0
# 8             0         2
# 10            4         3
